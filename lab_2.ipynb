# %% [markdown]
# # Simulation of the wireless communication system project in Signals and transforms

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
import wcslib as wcs
import sounddevice as sd

from parameters import Tb, dt, fc, fs, Ts, Kc, xc, xm;
from scipy.signal import butter, filtfilt


from transmitter import main as main_t


from receiver import main as main_r


# %matplotlib ipympl
pi = np.pi

# %% [markdown]
# ## Parameters

# %%
# TODO: Add your parameters here. You might need to add other parameters as well.
channel_id = 14   # Your channel ID

# Message to be transmitted
data = "Hello World!"

# %% [markdown]
# ## Filter design

# %%
# TODO: Design the filters
def bandpass_filter(x, lowcut, highcut, fs, order):
    nyq = fs / 2                     # Nyquist-frekvens
    low = lowcut / nyq
    high = highcut / nyq

    b, a = butter(order, [low, high], btype='band')
    y = filtfilt(b, a, x)            # Zero-phase filtering
    return y

# %% [markdown]
# ## Transmitter

# %%
# Convert string to bit sequence
bs = wcs.encode_string(data)

# Encode baseband signal
xb = wcs.encode_baseband_signal(bs, Tb)

t = np.arange(0, xb.shape[0])*dt

# TODO: Implement transmitter code here
wc = fc*2 * np.pi
xc = np.sin(wc * t) * np.sqrt(2)
xm = xc * xb

xt = bandpass_filter(xm, 3750, 3850, fs, 4)


# # TODO: Put your transmitter code here (modulation, filtering, etc.)
# bit_seq = np.random.randint(2, size=10)
# xb = wcs.encode_baseband_signal(bit_seq, Tb)
# t = np.arange(0, xb.shape[0])*dt

# # TODO: Implement transmitter code here
# wc = fc*2 * np.pi
# xc = np.sin(wc * t) * np.sqrt(2)
# xm = xc * xb
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 14
#      11 xc = np.sin(wc * t) * np.sqrt(2)
#      12 xm = xc * xb
# ---> 14 xt = bandpass_filter(xm, 3750, 3850, fs, 4)
#      17 # # TODO: Put your transmitter code here (modulation, filtering, etc.)
#      18 # bit_seq = np.random.randint(2, size=10)
#      19 # xb = wcs.encode_baseband_signal(bit_seq, Tb)
#    (...)     24 # xc = np.sin(wc * t) * np.sqrt(2)
#      25 # xm = xc * xb
#
# Cell In[69], line 7, in bandpass_filter(x, lowcut, highcut, fs, order)
#       4 low = lowcut / nyq
#       5 high = highcut / nyq
# ----> 7 b, a = butter(order, [low, high], btype='band')
#       8 y = filtfilt(b, a, x)            # Zero-phase filtering
#       9 return y
#
# File c:\Users\albin\OneDrive\Skrivbord\Skola\SigTrans\SigTrans-Projekt\.venv\Lib\site-packages\scipy\signal\_filter_design.py:3475, in butter(N, Wn, btype, analog, output, fs)
#    3354 def butter(N, Wn, btype='low', analog=False, output='ba', fs=None):
#    3355     """
#    3356     Butterworth digital and analog filter design.
#    3357
#    (...)   3473     >>> plt.show()
#    3474     """
# -> 3475     return iirfilter(N, Wn, btype=btype, analog=analog,
#    3476                      output=output, ftype='butter', fs=fs)
#
# File c:\Users\albin\OneDrive\Skrivbord\Skola\SigTrans\SigTrans-Projekt\.venv\Lib\site-packages\scipy\signal\_filter_design.py:2847, in iirfilter(N, Wn, rp, rs, btype, analog, ftype, output, fs)
#    2844     if fs is not None:
#    2845         raise ValueError("Digital filter critical frequencies must "
#    2846                          f"be 0 < Wn < fs/2 (fs={fs} -> fs/2={fs/2})")
# -> 2847     raise ValueError("Digital filter critical frequencies "
#    2848                      "must be 0 < Wn < 1")
#    2849 fs = 2.0
#    2850 warped = 2 * fs * tan(pi * Wn / fs)
#
# ValueError: Digital filter critical frequencies must be 0 < Wn < 1

# %% [markdown]
# ## Simulate transmission

# %%
yr = wcs.simulate_channel(xt, fs, channel_id)

# %% [markdown]
# ## Receiver

# %%
# args = parser.parse_args()

#     # Set parameters
# T = args.duration

# # TODO: Put your receiver code (filtering, demodulation, etc.) here
# yr = sd.rec(int(T/dt), samplerate=1/dt, channels=1, blocking=True)
# yr = yr[:, 0]           # Remove second channel

# # TODO: Implement demodulation, etc. here
# # ...
# yb = yr * xc
# # Baseband signal
# # yb = ...


# # Symbol decoding
# # TODO: Adjust fs (lab 2 only, leave untouched for lab 1 unless you know what you are doing)
# br = wcs.decode_baseband_signal(yb, Tb, 1/dt)
# data_rx = wcs.decode_string(br)
# print(f'Received: {data_rx} (no of bits: {len(br)}).')



ybi = 

ybg = 
# Calculate complex baseband signal
yb = ybi + 1j*ybq

# Symbol decoding
br = wcs.decode_baseband_signal(yb, Tb, fs)

data_rx = wcs.decode_string(br)
print('Received: ' + data_rx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # TODO: Put your receiver code (filtering, demodulation, etc.) here
# ----> 2 yr = sd.rec(int(T/dt), samplerate=1/dt, channels=1, blocking=True)
#       3 yr = yr[:, 0]           # Remove second channel
#       5 # TODO: Implement demodulation, etc. here
#       6 # ...
#
# NameError: name 'T' is not defined
